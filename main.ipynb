# %%
import pandas as pd
from pandas import Series,DataFrame
ny_df = pd.read_csv('NYPD_7_Major_Felony_Incidents.csv')
pd.set_option("display.max_columns", 20)

# %%
ny_df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>OBJECTID</th>
#       <th>Identifier</th>
#       <th>Occurrence Date</th>
#       <th>Day of Week</th>
#       <th>Occurrence Month</th>
#       <th>Occurrence Day</th>
#       <th>Occurrence Year</th>
#       <th>Occurrence Hour</th>
#       <th>CompStat Month</th>
#       <th>CompStat Day</th>
#       <th>CompStat Year</th>
#       <th>Offense</th>
#       <th>Offense Classification</th>
#       <th>Sector</th>
#       <th>Precinct</th>
#       <th>Borough</th>
#       <th>Jurisdiction</th>
#       <th>XCoordinate</th>
#       <th>YCoordinate</th>
#       <th>Location 1</th>
#     </tr>
#   </thead>
# ...

# %%
ny_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1117273 entries, 257 to 1123463
# Data columns (total 14 columns):
# Day of Week         1117273 non-null object
# Occurrence Month    1117273 non-null object
# Occurrence Day      1117273 non-null float64
# Occurrence Year     1117273 non-null float64
# Occurrence Hour     1117273 non-null float64
# CompStat Month      1117273 non-null float64
# CompStat Day        1117273 non-null float64
# CompStat Year       1117273 non-null float64
# Offense             1117273 non-null object
# Precinct            1117256 non-null float64
# Borough             1117199 non-null object
# XCoordinate         1117273 non-null float64
# YCoordinate         1117273 non-null float64
# Location 1          1117273 non-null object
# dtypes: float64(9), object(5)
# memory usage: 127.9+ MB

# %%
# Find null data
null_columns=ny_df.columns[ny_df.isnull().any()]
print(ny_df[null_columns].isnull().sum())
# print(ny_df[ny_df.isnull().any(axis=1)][null_columns].head(20))
print(ny_df[ny_df.isnull().any(axis=1)][null_columns].head(20))
# Out:
# Precinct    17
# Borough     74
# dtype: int64
#          Precinct        Borough
# 23135         NaN         (null)
# 36231         NaN         (null)
# 1118928       NaN      MANHATTAN
# 1118946       NaN       BROOKLYN
# 1119122       NaN  STATEN ISLAND
# 1119138       NaN       BROOKLYN
# 1119313       NaN      MANHATTAN
# 1119401       NaN          BRONX
# 1119481       NaN      MANHATTAN
# 1119767       NaN  STATEN ISLAND
# 1119846       NaN          BRONX
# 1119881       NaN         QUEENS
# 1119924       NaN       BROOKLYN
# 1120576      79.0            NaN
# 1120901      52.0            NaN
# 1121099      72.0            NaN
# 1121122      33.0            NaN
# 1121168      61.0            NaN
# 1121169      61.0            NaN
# 1121170      61.0            NaN
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-b289e401f5ae> in <module>()
# ...

# %%
# del unnecessary colums 
drop_col = ['Occurrence Date', 'OBJECTID', 'Identifier', 'Offense Classification','Sector','Jurisdiction']
ny_df =ny_df.drop(drop_col, axis=1)

# %%
# only interested in offenses in last 10 years [2006, 2015]
ny_df=ny_df[ny_df['Occurrence Year']>=2006]
#Drop the rows where at least one element is missing.
# ny_df.dropna()
