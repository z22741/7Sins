# %%
# Imports

# Visualisations
import matplotlib.pyplot as plt 
import matplotlib
import seaborn as sns
plt.style.use('fivethirtyeight')
# %matplotlib inline

# Warnings
import warnings
warnings.filterwarnings('ignore')

# Data exploration
import pandas as pd

# Numerical
import numpy as np

# Spatial analysis
import geopandas as gpd   # used to read .shp file
from shapely.geometry import Point, Polygon, shape

# Regular expressions
import re

# Random
np.random.seed(11)

# %%
dft1 = pd.read_csv("./Data/NYPD_Complaint_Data_Current__Year_To_Date_.csv")
dft1.head()
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 0   457872064          113    QUEENS   06/30/2018     23:30:00   06/30/2018
# 1   271939965          115    QUEENS   06/30/2018     23:20:00   06/30/2018
# 2   862644726           94  BROOKLYN   06/30/2018     23:09:00   06/30/2018
# 3   354814756           41     BRONX   06/30/2018     23:00:00   06/30/2018
# 4   963900505           43     BRONX   06/30/2018     23:00:00   06/30/2018
#
#   CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# 0     23:40:00        COMPLETED        NaN          NaN
# 1     23:25:00        COMPLETED        NaN          NaN
# 2     23:25:00        COMPLETED        NaN          NaN
# 3     23:19:00        COMPLETED        NaN          NaN
# 4     23:29:00        COMPLETED     MONROE        911.0
#
#                ...                SUSP_SEX TRANSIT_DISTRICT  VIC_AGE_GROUP  \
# 0              ...                       M              NaN          18-24
# 1              ...                       M              NaN          18-24
# 2              ...                       M              NaN          45-64
# 3              ...                       M              NaN        UNKNOWN
# 4              ...                       M              NaN          18-24
#
#          VIC_RACE VIC_SEX X_COORD_CD Y_COORD_CD   Latitude  Longitude  \
# 0           BLACK       F  1048111.0   188479.0  40.683786 -73.769746
# 1   ASIAN/PAC.ISL       M  1017940.0   214837.0  40.756298 -73.878397
# 2   ASIAN/PAC.ISL       M   997245.0   204130.0  40.726965 -73.953117
# 3         UNKNOWN       E  1012522.0   239685.0  40.824519 -73.897849
# 4  WHITE HISPANIC       F  1021060.0   238980.0  40.822552 -73.867003
#
#                          Lat_Lon
# 0   (40.68378593, -73.769745503)
# 1  (40.756298483, -73.878397328)
# 2  (40.726965067, -73.953116629)
# 3  (40.824518508, -73.897849003)
# 4  (40.822552032, -73.867003392)
#
# [5 rows x 35 columns]

# %% [markdown]
# | Index | Column Name | Column Description |
# | --- | --- | --- |
# | 0 | CMPLNT_NUM	 | Unique ID |
# | 1,2 | CMPLNT_FR_DT, CMPLNT_FR_TM	 | Complaint From Date and Time |
# | 3,4 | CMPLNT_TO_DT, CMPLNT_TO_TM	 | Complaint To Date and Time |
# | 5 | RPT_DT | Report Date |
# | 6,7 | KY_CD, OFNS_DESC | Criminal ID and Description |
# | 8, 9 | PD_CD, PD_DESC | Police Department Code and Description |
# | 10 | CRM_ATPT_CPTD_CD | Completed, Attempted but Fail, etc. |
# | 11 | ADDR_PCT_CD |  |
# | 13 | HADEVELOPT |  |
# | 14 | HOUSING_PSA |  |
# | 15 | STATION_NAME |  |
# | 16 | SUSP_AGE_GROUP | Suspect Age Group |
# | 17 | SUSP_RACE | Suspect Race |
# | 18 | SUSP_SEX | Suspect Sex |
# | 19 | TRANSIT_DISTRICT |  |
# | 20 | VIC_AGE_GROUP	 | Victim Age Group |
# | 21,22 | VIC_RACE | Victim Race |
# | 23 | VIC_SEX | Victim Sex |
# | 24,25 | X_COORD_CD | Latitude |
# | 26,27 | Y_COORD_CD | Longitude |
# | 28 | Longitude		 |  |
# | 29 | PATROL_BORO | |
# | 30 | Latitude |  |
# | 31 | Lat_Lon | |

# %% [markdown]
# Restricting our analysis to last 8 years

# %% [markdown]
# ### Dimensionality Reduction ###
#
# - Drop columns not pertaining to our analysis.<br>
#   - HADEVELOPT	NYCHA Housing Development<br>
#   - LOC_OF_OCCUR_DESC Location of occurence.Since the level of granularity for this analysis is restricted to the boroughs this column could be dropped.
# - Irrelevant attributes to our data mining task<br>
#   - HOUSING_PSA<br>
#   - PARK_NM<br>
#   - JURISDICTION_CODE<br>
#   - PATROL_BORO <br>
#   - STATION_NAME<br>
#   - SUSP_AGE_GROUP<br>
#   - SUSP_RACE<br>
#   - SUSP_SEX<br>
#   - TRANSIT_DISTRICT<br>
#   - VIC_AGE_GROUP<br>
#   - VIC_RACE<br>
#   - VIC_SEX<br>

# %%
dft1=dft1.drop(columns=["HADEVELOPT","LOC_OF_OCCUR_DESC","HOUSING_PSA","PARKS_NM","JURISDICTION_CODE","PATROL_BORO","STATION_NAME","SUSP_AGE_GROUP","SUSP_RACE","SUSP_SEX","TRANSIT_DISTRICT","VIC_AGE_GROUP","VIC_RACE","VIC_SEX"])
dft1.head()
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 0   457872064          113    QUEENS   06/30/2018     23:30:00   06/30/2018
# 1   271939965          115    QUEENS   06/30/2018     23:20:00   06/30/2018
# 2   862644726           94  BROOKLYN   06/30/2018     23:09:00   06/30/2018
# 3   354814756           41     BRONX   06/30/2018     23:00:00   06/30/2018
# 4   963900505           43     BRONX   06/30/2018     23:00:00   06/30/2018
#
#   CMPLNT_TO_TM CRM_ATPT_CPTD_CD           JURIS_DESC  KY_CD  \
# 0     23:40:00        COMPLETED     N.Y. POLICE DEPT    578
# 1     23:25:00        COMPLETED     N.Y. POLICE DEPT    578
# 2     23:25:00        COMPLETED     N.Y. POLICE DEPT    343
# 3     23:19:00        COMPLETED     N.Y. POLICE DEPT    235
# 4     23:29:00        COMPLETED  N.Y. HOUSING POLICE    344
#
#                ...                                     OFNS_DESC  PD_CD  \
# 0              ...                                 HARRASSMENT 2  637.0
# 1              ...                                 HARRASSMENT 2  637.0
# 2              ...                OTHER OFFENSES RELATED TO THEF  478.0
# 3              ...                               DANGEROUS DRUGS  567.0
# 4              ...                  ASSAULT 3 & RELATED OFFENSES  114.0
#
#                           PD_DESC               PREM_TYP_DESC      RPT_DT  \
# 0      HARASSMENT,SUBD 1,CIVILIAN                      STREET  06/30/2018
# 1      HARASSMENT,SUBD 1,CIVILIAN                   FAST FOOD  06/30/2018
# 2  THEFT OF SERVICES, UNCLASSIFIE      TAXI (LIVERY LICENSED)  06/30/2018
# 3     MARIJUANA, POSSESSION 4 & 5             PARK/PLAYGROUND  06/30/2018
# 4             OBSTR BREATH/CIRCUL  RESIDENCE - PUBLIC HOUSING  06/30/2018
#
#   X_COORD_CD  Y_COORD_CD   Latitude  Longitude                        Lat_Lon
# 0  1048111.0    188479.0  40.683786 -73.769746   (40.68378593, -73.769745503)
# 1  1017940.0    214837.0  40.756298 -73.878397  (40.756298483, -73.878397328)
# 2   997245.0    204130.0  40.726965 -73.953117  (40.726965067, -73.953116629)
# 3  1012522.0    239685.0  40.824519 -73.897849  (40.824518508, -73.897849003)
# 4  1021060.0    238980.0  40.822552 -73.867003  (40.822552032, -73.867003392)
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Missing value handling ###
#
# - CMPLN_TO_DT - filled missing values with CMPLNT_FR_DT or RPT_DT means incident lasted a day
# - CMPLNT_TO_TM - filled missing values with CMPLMNT_FR_TM means incident occured but did no last long - it is a kind of - -- simplification, detailed analysis of incidents' time is not point of thie kernel

# %%
df3=dft1[['CMPLNT_FR_DT','CMPLNT_TO_DT','RPT_DT']]
df3.tail()
# Out:
#        CMPLNT_FR_DT CMPLNT_TO_DT      RPT_DT
# 228900   03/12/2015   12/28/2017  01/01/2018
# 228901   01/01/2013   01/01/2018  01/01/2018
# 228902   04/12/2012   01/01/2018  01/01/2018
# 228903   10/21/2011   01/01/2018  01/01/2018
# 228904   01/01/2008   01/01/2018  01/01/2018

# %%
#Filling out nans in complaint from date
def datef(row):
    
    if pd.isnull(row["CMPLNT_FR_DT"]):
        if pd.notnull((row["CMPLNT_TO_DT"])):
            return row["CMPLNT_TO_DT"]
        elif pd.notnull(row['RPT_DT']):
            return row['RPT_DT']
        else: 
            return row["CMPLNT_FR_DT"]
    else: 
        return row["CMPLNT_FR_DT"]
dft1["CMPLNT_FR_DT"]=dft1.apply(datef,axis=1)
dft1.count()
# Out:
# CMPLNT_NUM          228905
# ADDR_PCT_CD         228905
# BORO_NM             228755
# CMPLNT_FR_DT        228905
# CMPLNT_FR_TM        228905
# CMPLNT_TO_DT        195321
# CMPLNT_TO_TM        195450
# CRM_ATPT_CPTD_CD    228905
# JURIS_DESC          228905
# KY_CD               228905
# LAW_CAT_CD          228905
# OFNS_DESC           228900
# PD_CD               228757
# PD_DESC             228757
# PREM_TYP_DESC       227918
# RPT_DT              228905
# X_COORD_CD          228891
# Y_COORD_CD          228891
# Latitude            228891
# Longitude           228891
# Lat_Lon             228891
# dtype: int64

# %% [markdown]
# - OFNS_DESC - 'OFNS_DESC' column has only 4 NaN values. Rows with those values have values in PD_DESC, so the best solution is to copy them.
# - PD_DESC - NaN values filled with OFNS_DESC values

# %%
# All NaNs from 'PD_DESC' series are filled with copy of 'OFNS_DESC' values
dft1['OFNS_DESC'] = np.where(dft1['OFNS_DESC'].isnull(), dft1['PD_DESC'], dft1['OFNS_DESC']) # There is pandas equivalent of np.where -> https://stackoverflow.com/questions/38579532/pandas-equivalent-of-np-where
# And vice versa
dft1['PD_DESC'] = np.where(dft1['PD_DESC'].isnull(), dft1['OFNS_DESC'], dft1['PD_DESC'])

# Sanity check
print(dft1['OFNS_DESC'].notnull().value_counts()) 
print(dft1['PD_DESC'].notnull().value_counts())
# Out:
# True    228905
# Name: OFNS_DESC, dtype: int64
# True    228905
# Name: PD_DESC, dtype: int64

# %%
# There are 2 rows without values in localization series, both are from BRONX, fill it with location from bronx according to ADDR_PCT_CD value
dft1['Latitude'].fillna(40.821054, inplace = True)
dft1['Longitude'].fillna(-73.893848, inplace = True)

# %% [markdown]
# - Latitude & Longitude - there are 2 rows with NaNs in these columns, so I chceked ADDR_PCT_CD value and found that is Bronx, picked random location in Bronx (manually) for these 2 NaNs
# - X_COORD_CD & Y_COORD_CD - NaNs filled with converted Latitude and Longitude
# - Lat_Lon - filled with latitude and longitude as a string type

# %% [markdown]
# - PREM_TYP_DESC - fill NaNs with randomly picked values from locations with appropriate content

# %%
# Creat copy to calculate proportions.
prem_typ_desc_copy = dft1['PREM_TYP_DESC'].copy(deep = True)
prem_typ_desc_copy_rand = prem_typ_desc_copy.value_counts(normalize = True).sort_values(ascending = False)

# Fill PREM_TYP_DESC values NaN values with values from locations of other incidents.
dft1['PREM_TYP_DESC'] = dft1['PREM_TYP_DESC'].apply(lambda x: np.random.choice([x for x in dft1.prem_typ_desc],
                          replace = True, p = prem_typ_desc_copy_rand ) if (x == np.nan) else x).astype(str)

# %% [markdown]
# - Borough - It's time to fill NaN values in BORO_NM column. I think there is one easy, but work demanding way to fill them. NY Boroughs boundaries data will be needed. It could be obtained from NYC Open Data or directly from geopandas package which seems easier solution. Here we use data from NYC open data

# %%
# Values of BORO_NM colum.
dft1['BORO_NM'].value_counts(dropna = False)
# Out:
# BROOKLYN         67489
# MANHATTAN        56691
# BRONX            50153
# QUEENS           44137
# STATEN ISLAND    10285
# NaN                150
# Name: BORO_NM, dtype: int64

# %%
# Find rows with NaN values in crimes data frame.
nan_boros = dft1[dft1['BORO_NM'].isnull()]
nan_boros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 64 to 228133
# Data columns (total 21 columns):
# CMPLNT_NUM          150 non-null int64
# ADDR_PCT_CD         150 non-null int64
# BORO_NM             0 non-null object
# CMPLNT_FR_DT        150 non-null object
# CMPLNT_FR_TM        150 non-null object
# CMPLNT_TO_DT        1 non-null object
# CMPLNT_TO_TM        1 non-null object
# CRM_ATPT_CPTD_CD    150 non-null object
# JURIS_DESC          150 non-null object
# KY_CD               150 non-null int64
# LAW_CAT_CD          150 non-null object
# OFNS_DESC           150 non-null object
# PD_CD               2 non-null float64
# PD_DESC             150 non-null object
# PREM_TYP_DESC       150 non-null object
# RPT_DT              150 non-null object
# X_COORD_CD          150 non-null float64
# Y_COORD_CD          150 non-null float64
# Latitude            150 non-null float64
# Longitude           150 non-null float64
# Lat_Lon             150 non-null object
# dtypes: float64(5), int64(3), object(13)
# memory usage: 25.8+ KB

# %% [markdown]
# The idea of finding BORO_NM value is simple. Longitude and latitude values of incidents from crimes data frame indicates if point of interest lies within boundries of one from 5 different boroughs. to check it it will be used shapely package.

# %%
# Import NYC Borough boundries shape file. It is important to read in file using geopandas instead of pandas.
boros = gpd.read_file('./Data/geo_export_366953f5-d29c-43ab-9e8e-781c703ad083.shp')
boros['boro_name'] = boros['boro_name'].str.upper()
boros
# Out:
#        boro_name  boro_code     shape_leng    shape_area  \
# 0      MANHATTAN        1.0  361649.881587  6.366006e+08
# 1          BRONX        2.0  463464.521828  1.186615e+09
# 2  STATEN ISLAND        5.0  330432.867999  1.623921e+09
# 3       BROOKLYN        3.0  739945.437431  1.937567e+09
# 4         QUEENS        4.0  895228.960360  3.044772e+09
#
#                                             geometry
# 0  (POLYGON ((-74.01092841268031 40.6844914725429...
# 1  (POLYGON ((-73.89680883223774 40.7958084451597...
# 2  (POLYGON ((-74.05050806403247 40.5664220341608...
# 3  (POLYGON ((-73.86706149472118 40.5820879767934...
# 4  (POLYGON ((-73.83668274106707 40.5949466970158...

# %%
# Function to make points - credits for https://twitter.com/dangerscarf
def make_point(row):
    return Point(row.Longitude, row.Latitude)

# Go through every row, and make a point out of its lon and lat
points = dft1.apply(make_point, axis=1)

# New GeoDataFrame with old data and new geometry
dft1_geo = gpd.GeoDataFrame(dft1, geometry = points)

# It doesn't come with a CRS because it's a CSV, so let's change it. I didn`t dive deep into it,
# but I have read, that it`s needed to get right results.
dft1_geo.crs = {'init': 'epsg:4326'}

# dft1_geo.head()

# %%
# Fill NaN values in BORO_NM
def fill_boro_nan(gdf1, gdf2):
    """ 
    Function fills NaN values in BORO_NM column in geodataframe and returns gdf with filled values.
    gdf1 - geodataframe with NaN values and POINTS
    gdf2 - geodataframe with POLYGONS and borougs names
    """
    boro_list = [] # List for keeping values of BORO_NM
    for point in gdf1['geometry'][gdf1['BORO_NM'].isnull()]:   # Iterate through rows with NaN values in BORO_NM column
        for i in range(0, len(gdf2['geometry'])):   # Iterate through rows of boros data frame
            if point.within(gdf2['geometry'][i]):   # Check if incident is within boundaries of one of boroughs
                gdf1['BORO_NM'][gdf1['BORO_NM'].isnull()][i] = gdf2['boro_name'][i]   # Ascribe borough name to incident location
                boro_list.append(gdf2['boro_name'][i])   # Make a list of boroughs
      
    boro_s = pd.Series(v for v in boro_list)    # Change list to series
    gdf1['BORO_NM'][gdf1['BORO_NM'].isnull()] = boro_s.values    # Fill NaN values in BORO_NM
    return boro_s    # Will be usefull to check if fills are correct

# %%
#Execute
boro_s = fill_boro_nan(dft1_geo, boros)

# %%
# Check values
dft1_geo['BORO_NM'].value_counts(dropna = False)
# Out:
# BROOKLYN         67540
# MANHATTAN        56707
# BRONX            50204
# QUEENS           44166
# STATEN ISLAND    10288
# Name: BORO_NM, dtype: int64

# %%
dft2=dft1.drop(columns=['CMPLNT_TO_DT',
       'CMPLNT_TO_TM', 'RPT_DT'])
dft2.head()
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD   BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0   457872064          113    QUEENS   06/30/2018     23:30:00
# 1   271939965          115    QUEENS   06/30/2018     23:20:00
# 2   862644726           94  BROOKLYN   06/30/2018     23:09:00
# 3   354814756           41     BRONX   06/30/2018     23:00:00
# 4   963900505           43     BRONX   06/30/2018     23:00:00
#
#   CRM_ATPT_CPTD_CD           JURIS_DESC  KY_CD   LAW_CAT_CD  \
# 0        COMPLETED     N.Y. POLICE DEPT    578    VIOLATION
# 1        COMPLETED     N.Y. POLICE DEPT    578    VIOLATION
# 2        COMPLETED     N.Y. POLICE DEPT    343  MISDEMEANOR
# 3        COMPLETED     N.Y. POLICE DEPT    235  MISDEMEANOR
# 4        COMPLETED  N.Y. HOUSING POLICE    344  MISDEMEANOR
#
#                         OFNS_DESC  PD_CD                         PD_DESC  \
# 0                   HARRASSMENT 2  637.0      HARASSMENT,SUBD 1,CIVILIAN
# 1                   HARRASSMENT 2  637.0      HARASSMENT,SUBD 1,CIVILIAN
# 2  OTHER OFFENSES RELATED TO THEF  478.0  THEFT OF SERVICES, UNCLASSIFIE
# 3                 DANGEROUS DRUGS  567.0     MARIJUANA, POSSESSION 4 & 5
# 4    ASSAULT 3 & RELATED OFFENSES  114.0             OBSTR BREATH/CIRCUL
#
#                 PREM_TYP_DESC  X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 0                      STREET   1048111.0    188479.0  40.683786 -73.769746
# 1                   FAST FOOD   1017940.0    214837.0  40.756298 -73.878397
# 2      TAXI (LIVERY LICENSED)    997245.0    204130.0  40.726965 -73.953117
# 3             PARK/PLAYGROUND   1012522.0    239685.0  40.824519 -73.897849
# 4  RESIDENCE - PUBLIC HOUSING   1021060.0    238980.0  40.822552 -73.867003
#
#                          Lat_Lon                                      geometry
# 0   (40.68378593, -73.769745503)             POINT (-73.769745503 40.68378593)
# 1  (40.756298483, -73.878397328)       POINT (-73.87839732800001 40.756298483)
# 2  (40.726965067, -73.953116629)  POINT (-73.95311662899999 40.72696506699999)
# 3  (40.824518508, -73.897849003)            POINT (-73.897849003 40.824518508)
# 4  (40.822552032, -73.867003392)            POINT (-73.867003392 40.822552032)

# %%
dft2.rename(columns={'CMPLNT_NUM':'ComplaintID', 'CMPLNT_FR_DT':'Date','CMPLNT_FR_TM':'Time',"KY_CD":"Offence Code",'OFNS_DESC':'Description','PD_CD':'Internal Code',
 'PD_DESC':'Internal Description',
 'CRM_ATPT_CPTD_CD':'Status',
 'LAW_CAT_CD':'Offence Level',
 'BORO_NM':'Borough',
 'ADDR_PCT_CD':'Neighborhood',
 'PREM_TYP_DESC':'Premise Description'}, inplace=True)

dft2.reset_index(inplace=True)
dft2.drop(columns='index')
# Out:
#         ComplaintID  Neighborhood        Borough        Date      Time  \
# 0         457872064           113         QUEENS  06/30/2018  23:30:00
# 1         271939965           115         QUEENS  06/30/2018  23:20:00
# 2         862644726            94       BROOKLYN  06/30/2018  23:09:00
# 3         354814756            41          BRONX  06/30/2018  23:00:00
# 4         963900505            43          BRONX  06/30/2018  23:00:00
# 5         909411087           104         QUEENS  06/30/2018  23:00:00
# 6         287643706            67       BROOKLYN  06/30/2018  23:00:00
# 7         963520368            42          BRONX  06/30/2018  22:55:00
# 8         662959967            44          BRONX  06/30/2018  22:55:00
# 9         116423095            41          BRONX  06/30/2018  22:50:00
# 10        585148547            28      MANHATTAN  06/30/2018  22:50:00
# 11        586617249            52          BRONX  06/30/2018  22:50:00
# 12        371765635           114         QUEENS  06/30/2018  22:50:00
# 13        549638292            79       BROOKLYN  06/30/2018  22:45:00
# 14        244320790            24      MANHATTAN  06/30/2018  22:40:00
# 15        552681805            90       BROOKLYN  06/30/2018  22:40:00
MPLETED     N.Y. POLICE DEPT           578     VIOLATION
# 7       COMPLETED     N.Y. POLICE DEPT           109        FELONY
# 8       COMPLETED     N.Y. POLICE DEPT           578     VIOLATION
# 9       COMPLETED     N.Y. POLICE DEPT           235   MISDEMEANOR
# 10      COMPLETED     N.Y. POLICE DEPT           341   MISDEMEANOR
# 11      COMPLETED     N.Y. POLICE DEPT           113        FELONY
# 12      COMPLETED     N.Y. POLICE DEPT           578     VIOLATION
# 13      COMPLETED     N.Y. POLICE DEPT           106        FELONY
# 14      COMPLETED     N.Y. POLICE DEPT           344   MISDEMEANOR
# 15      COMPLETED     N.Y. POLICE DEPT           106        FELONY
# 16      COMPLETED  N.Y. HOUSING POLICE           578     VIOLATION
# 17      COMPLETED     N.Y. POLICE DEPT           233   MISDEMEANOR
# 18      COMPLETED     N.Y. POLICE DEPT           355   MISDEMEANOR
# 19      COMPLETED     N.Y. POLICE DEPT           235   MISDEMEANOR
# 20      COMPLETED     N.Y. POLICE DEPT           578     VIOLATION
# 21      COMPLETED     N.Y. POLICE DEPT           578     VIOLATION
# 22      COMPLETED     N.Y. POLICE DEPT           126        FELONY
# 23      COMPLETED     N.Y. POLICE DEPT           341   MISDEMEANOR
# 24      ATTEMPTED     N.Y. POLICE DEPT           235   MISDEMEANOR
# 25      COMPLETED     N.Y. POLICE DEPT           341   MISDEMEANOR
# 26      COMPLETED     N.Y. POLICE DEPT           341   MISDEMEANOR
# 27      COMPLETED     N.Y. POLICE DEPT           113        FELONY
# 28      COMPLETED     N.Y. POLICE DEPT           126        FELONY
# 29      COMPLETED  N.Y. HOUSING POLICE           106        FELONY
# ...           ...                  ...           ...           ...
# 228875  COMPLETED     N.Y. POLICE DEPT           341   MISDEMEANOR
# 228876  COMPLETED     N.Y. POLICE DEPT           578     VIOLATION
# 228877  COMPLETED     N.Y. POLICE DEPT           341   MISDEMEANOR
# 228878  COMPLETED     N.Y. POLICE DEPT           341   MISDEMEANOR
# 228879  COMPLETED  N.Y. HOUSING POLICE           341   MISDEMEANOR
# 228880  COMPLETED     N.Y. POLICE DEPT           341   MISDEMEANOR
# 228881  COMPLETED     N.Y. POLICE DEPT           121        FELONY
# 228882  COMPLETED     N.Y. POLICE DEPT           578     VIOLATION
# 228883  COMPLETED     N.Y. POLICE DEPT           109        FELONY
# 228884  COMPLETED     N.Y. POLICE DEPT           109        FELONY
# 228885  COMPLETED     N.Y. POLICE DEPT           361   MISDEMEANOR
# 228886  COMPLETED  N.Y. HOUSING POLICE           578     VIOLATION
# 228887  COMPLETED     N.Y. POLICE DEPT           109        FELONY
# 228888  COMPLETED     N.Y. POLICE DEPT           106        FELONY
# 228889  COMPLETED     N.Y. POLICE DEPT           341   MISDEMEANOR
# 228890  COMPLETED     N.Y. POLICE DEPT           341   MISDEMEANOR
# 228891  COMPLETED     N.Y. POLICE DEPT           109        FELONY
# 228892  COMPLETED  N.Y. HOUSING POLICE           361   MISDEMEANOR
# 228893  COMPLETED     N.Y. POLICE DEPT           112        FELONY
# 228894  COMPLETED     N.Y. POLICE DEPT           341   MISDEMEANOR
# 228895  COMPLETED  N.Y. HOUSING POLICE           113        FELONY
# 228896  COMPLETED     N.Y. POLICE DEPT           578     VIOLATION
# 228897  COMPLETED     N.Y. POLICE DEPT           344   MISDEMEANOR
# 228898  COMPLETED     N.Y. POLICE DEPT           233   MISDEMEANOR
# 228899  COMPLETED     N.Y. POLICE DEPT           116        FELONY
# 228900  COMPLETED  N.Y. HOUSING POLICE           341   MISDEMEANOR
# 228901  COMPLETED     N.Y. POLICE DEPT           578     VIOLATION
# 228902  COMPLETED     N.Y. POLICE DEPT           109        FELONY
# 228903  COMPLETED     N.Y. POLICE DEPT           109        FELONY
# 228904  COMPLETED     N.Y. POLICE DEPT           344   MISDEMEANOR
#
#                            Description  Internal Code  \
# 0                        HARRASSMENT 2          637.0
# 1                        HARRASSMENT 2          637.0
# 2       OTHER OFFENSES RELATED TO THEF          478.0
# 3                      DANGEROUS DRUGS          567.0
# 4         ASSAULT 3 & RELATED OFFENSES          114.0
# 5       INTOXICATED & IMPAIRED DRIVING          905.0
# 6                        HARRASSMENT 2          638.0
# 7                        GRAND LARCENY          404.0
# 8                        HARRASSMENT 2          638.0
# 9                      DANGEROUS DRUGS          567.0
# 10                       PETIT LARCENY          333.0
# 11                             FORGERY          729.0
# 12                       HARRASSMENT 2          637.0
# 13                      FELONY ASSAULT          105.0
# 14        ASSAULT 3 & RELATED OFFENSES          101.0
# 15                      FELONY ASSAULT          109.0
# 16                       HARRASSMENT 2          638.0
# 17                          SEX CRIMES          681.0
# 18         OFFENSES AGAINST THE PERSON          115.0
# 19                     DANGEROUS DRUGS          511.0
# 20                       HARRASSMENT 2          637.0
# 21                       HARRASSMENT 2          637.0
# 22             MISCELLANEOUS PENAL LAW          198.0
# 23                       PETIT LARCENY          333.0
# 24                     DANGEROUS DRUGS          511.0
# 25                       PETIT LARCENY          338.0
# 26                       PETIT LARCENY          333.0
# 27                             FORGERY          729.0
# 28             MISCELLANEOUS PENAL LAW          198.0
# 29                      FELONY ASSAULT          105.0
# ...                                ...            ...
# 228875                   PETIT LARCENY          343.0
# 228876                   HARRASSMENT 2          638.0
# 228877                   PETIT LARCENY          347.0
# 228878                   PETIT LARCENY          347.0
# 228879                   PETIT LARCENY          338.0
# 228880                   PETIT LARCENY          333.0
# 228881  CRIMINAL MISCHIEF & RELATED OF          269.0
# 228882                   HARRASSMENT 2          638.0
# 228883                   GRAND LARCENY          418.0
# 228884                   GRAND LARCENY          430.0
# 228885   OFF. AGNST PUB ORD SENSBLTY &          639.0
# 228886                   HARRASSMENT 2          638.0
# 228887                   GRAND LARCENY          407.0
# 228888                  FELONY ASSAULT          109.0
# 228889                   PETIT LARCENY          349.0
# 228890                   PETIT LARCENY          339.0
# 228891                   GRAND LARCENY          437.0
# 228892   OFF. AGNST PUB ORD SENSBLTY &          639.0
# 228893                     THEFT-FRAUD          739.0
# 228894                   PETIT LARCENY          338.0
# 228895                         FORGERY          729.0
# 228896                   HARRASSMENT 2          637.0
# 228897    ASSAULT 3 & RELATED OFFENSES          101.0
# 228898                      SEX CRIMES          175.0
# 228899                      SEX CRIMES          168.0
# 228900                   PETIT LARCENY          339.0
# 228901                   HARRASSMENT 2          637.0
# 228902                   GRAND LARCENY          432.0
# 228903                   GRAND LARCENY          420.0
# 228904    ASSAULT 3 & RELATED OFFENSES          101.0
#
#                                      Internal Description  \
# 0                              HARASSMENT,SUBD 1,CIVILIAN
# 1                              HARASSMENT,SUBD 1,CIVILIAN
# 2                          THEFT OF SERVICES, UNCLASSIFIE
# 3                             MARIJUANA, POSSESSION 4 & 5
# 4                                     OBSTR BREATH/CIRCUL
# 5                             INTOXICATED DRIVING,ALCOHOL
# 6                                   HARASSMENT,SUBD 3,4,5
# 7       LARCENY,GRAND FROM PERSON,PERSONAL ELECTRONIC ...
# 8                                   HARASSMENT,SUBD 3,4,5
# 9                             MARIJUANA, POSSESSION 4 & 5
# 10                         LARCENY,PETIT FROM STORE-SHOPL
# 11                         FORGERY,ETC.,UNCLASSIFIED-FELO
# 12                             HARASSMENT,SUBD 1,CIVILIAN
# 13                                      STRANGULATION 1ST
# 14                                              ASSAULT 3
# 15                               ASSAULT 2,1,UNCLASSIFIED
# 16                                  HARASSMENT,SUBD 3,4,5
# 17                             CHILD, ENDANGERING WELFARE
# 18                                RECKLESS ENDANGERMENT 2
# 19                         CONTROLLED SUBSTANCE, POSSESSI
# 20                             HARASSMENT,SUBD 1,CIVILIAN
# 21                             HARASSMENT,SUBD 1,CIVILIAN
# 22                                    CRIMINAL CONTEMPT 1
# 23                         LARCENY,PETIT FROM STORE-SHOPL
# 24                         CONTROLLED SUBSTANCE, POSSESSI
# 25                         LARCENY,PETIT FROM BUILDING,UN
# 26                         LARCENY,PETIT FROM STORE-SHOPL
# 27                         FORGERY,ETC.,UNCLASSIFIED-FELO
# 28                                    CRIMINAL CONTEMPT 1
# 29                                      STRANGULATION 1ST
# ...                                                   ...
# 228875                           LARCENY,PETIT OF BICYCLE
# 228876                              HARASSMENT,SUBD 3,4,5
# 228877                     PETIT LARCENY-CHECK FROM MAILB
# 228878                     PETIT LARCENY-CHECK FROM MAILB
# 228879                     LARCENY,PETIT FROM BUILDING,UN
# 228880                     LARCENY,PETIT FROM STORE-SHOPL
# 228881                     MISCHIEF,CRIMINAL,    UNCL 2ND
# 228882                              HARASSMENT,SUBD 3,4,5
# 228883        LARCENY,GRAND BY ACQUIRING LOST CREDIT CARD
# 228884  LARCENY,GRAND BY BANK ACCT COMPROMISE-UNCLASSI...
# 228885                            AGGRAVATED HARASSMENT 2
# 228886                              HARASSMENT,SUBD 3,4,5
# 228887                     LARCENY,GRAND BY DISHONEST EMP
# 228888                           ASSAULT 2,1,UNCLASSIFIED
# 228889                     LARCENY,PETIT OF LICENSE PLATE
# 228890                     LARCENY,PETIT FROM OPEN AREAS,
# 228891   LARCENY,GRAND BY FALSE PROMISE-IN PERSON CONTACT
# 228892                            AGGRAVATED HARASSMENT 2
# 228893                          FRAUD,UNCLASSIFIED-FELONY
# 228894                     LARCENY,PETIT FROM BUILDING,UN
# 228895                     FORGERY,ETC.,UNCLASSIFIED-FELO
# 228896                         HARASSMENT,SUBD 1,CIVILIAN
# 228897                                          ASSAULT 3
# 228898                                   SEXUAL ABUSE 3,2
# 228899                                           SODOMY 1
# 228900                     LARCENY,PETIT FROM OPEN AREAS,
# 228901                         HARASSMENT,SUBD 1,CIVILIAN
# 228902       LARCENY,GRAND BY IDENTITY THEFT-UNCLASSIFIED
# 228903   LARCENY,GRAND BY OPEN/COMPROMISE CELL PHONE ACCT
# 228904                                          ASSAULT 3
#
#                Premise Description  X_COORD_CD  Y_COORD_CD   Latitude  \
# 0                           STREET   1048111.0    188479.0  40.683786
# 1                        FAST FOOD   1017940.0    214837.0  40.756298
# 2           TAXI (LIVERY LICENSED)    997245.0    204130.0  40.726965
# 3                  PARK/PLAYGROUND   1012522.0    239685.0  40.824519
# 4       RESIDENCE - PUBLIC HOUSING   1021060.0    238980.0  40.822552
# 5                           STREET   1014406.0    198825.0  40.712362
# 6                           STREET    997976.0    173170.0  40.641986
# 7                  PARK/PLAYGROUND   1012860.0    244801.0  40.838559
# 228900       POINT (-73.96540192499999 40.795780139)
# 228901             POINT (-73.82821878 40.677605279)
# 228902             POINT (-73.956567991 40.80663529)
# 228903            POINT (-73.965008102 40.761715092)
# 228904            POINT (-73.855873511 40.848284087)
#
# [228905 rows x 19 columns]

# %%
# to save some memory assign Borough, Status, Offence Level as 'category'
# To save some memory assign Borough, Status, Offence Level as 'category'
dft2['Borough']=dft2['Borough'].astype('category')
dft2['Offence Code']=dft2['Offence Code'].astype('category')
dft2['Internal Code']=dft2['Internal Code'].astype('category')
dft2['Status']=dft2['Status'].astype('category')
dft2['Offence Level']=dft2['Offence Level'].astype('category')
dft2['Neighborhood']=dft2['Neighborhood'].astype('category')

# %%
dft2.head()
# Out:
#    index  ComplaintID Neighborhood   Borough        Date      Time     Status  \
# 0      0    457872064          113    QUEENS  06/30/2018  23:30:00  COMPLETED
# 1      1    271939965          115    QUEENS  06/30/2018  23:20:00  COMPLETED
# 2      2    862644726           94  BROOKLYN  06/30/2018  23:09:00  COMPLETED
# 3      3    354814756           41     BRONX  06/30/2018  23:00:00  COMPLETED
# 4      4    963900505           43     BRONX  06/30/2018  23:00:00  COMPLETED
#
#             JURIS_DESC Offence Code Offence Level  \
# 0     N.Y. POLICE DEPT          578     VIOLATION
# 1     N.Y. POLICE DEPT          578     VIOLATION
# 2     N.Y. POLICE DEPT          343   MISDEMEANOR
# 3     N.Y. POLICE DEPT          235   MISDEMEANOR
# 4  N.Y. HOUSING POLICE          344   MISDEMEANOR
#
#                       Description Internal Code  \
# 0                   HARRASSMENT 2         637.0
# 1                   HARRASSMENT 2         637.0
# 2  OTHER OFFENSES RELATED TO THEF         478.0
# 3                 DANGEROUS DRUGS         567.0
# 4    ASSAULT 3 & RELATED OFFENSES         114.0
#
#              Internal Description         Premise Description  X_COORD_CD  \
# 0      HARASSMENT,SUBD 1,CIVILIAN                      STREET   1048111.0
# 1      HARASSMENT,SUBD 1,CIVILIAN                   FAST FOOD   1017940.0
# 2  THEFT OF SERVICES, UNCLASSIFIE      TAXI (LIVERY LICENSED)    997245.0
# 3     MARIJUANA, POSSESSION 4 & 5             PARK/PLAYGROUND   1012522.0
# 4             OBSTR BREATH/CIRCUL  RESIDENCE - PUBLIC HOUSING   1021060.0
#
#    Y_COORD_CD   Latitude  Longitude                        Lat_Lon  \
# 0    188479.0  40.683786 -73.769746   (40.68378593, -73.769745503)
# 1    214837.0  40.756298 -73.878397  (40.756298483, -73.878397328)
# 2    204130.0  40.726965 -73.953117  (40.726965067, -73.953116629)
# 3    239685.0  40.824519 -73.897849  (40.824518508, -73.897849003)
# 4    238980.0  40.822552 -73.867003  (40.822552032, -73.867003392)
#
#                                        geometry
# 0             POINT (-73.769745503 40.68378593)
# 1       POINT (-73.87839732800001 40.756298483)
# 2  POINT (-73.95311662899999 40.72696506699999)
# 3            POINT (-73.897849003 40.824518508)
# 4            POINT (-73.867003392 40.822552032)

# %%
dft2.drop(columns=['index'],inplace=True)

# %%
dft2.head()
# Out:
#    ComplaintID Neighborhood   Borough        Date      Time     Status  \
# 0    457872064          113    QUEENS  06/30/2018  23:30:00  COMPLETED
# 1    271939965          115    QUEENS  06/30/2018  23:20:00  COMPLETED
# 2    862644726           94  BROOKLYN  06/30/2018  23:09:00  COMPLETED
# 3    354814756           41     BRONX  06/30/2018  23:00:00  COMPLETED
# 4    963900505           43     BRONX  06/30/2018  23:00:00  COMPLETED
#
#             JURIS_DESC Offence Code Offence Level  \
# 0     N.Y. POLICE DEPT          578     VIOLATION
# 1     N.Y. POLICE DEPT          578     VIOLATION
# 2     N.Y. POLICE DEPT          343   MISDEMEANOR
# 3     N.Y. POLICE DEPT          235   MISDEMEANOR
# 4  N.Y. HOUSING POLICE          344   MISDEMEANOR
#
#                       Description Internal Code  \
# 0                   HARRASSMENT 2         637.0
# 1                   HARRASSMENT 2         637.0
# 2  OTHER OFFENSES RELATED TO THEF         478.0
# 3                 DANGEROUS DRUGS         567.0
# 4    ASSAULT 3 & RELATED OFFENSES         114.0
#
#              Internal Description         Premise Description  X_COORD_CD  \
# 0      HARASSMENT,SUBD 1,CIVILIAN                      STREET   1048111.0
# 1      HARASSMENT,SUBD 1,CIVILIAN                   FAST FOOD   1017940.0
# 2  THEFT OF SERVICES, UNCLASSIFIE      TAXI (LIVERY LICENSED)    997245.0
# 3     MARIJUANA, POSSESSION 4 & 5             PARK/PLAYGROUND   1012522.0
# 4             OBSTR BREATH/CIRCUL  RESIDENCE - PUBLIC HOUSING   1021060.0
#
#    Y_COORD_CD   Latitude  Longitude                        Lat_Lon  \
# 0    188479.0  40.683786 -73.769746   (40.68378593, -73.769745503)
# 1    214837.0  40.756298 -73.878397  (40.756298483, -73.878397328)
# 2    204130.0  40.726965 -73.953117  (40.726965067, -73.953116629)
# 3    239685.0  40.824519 -73.897849  (40.824518508, -73.897849003)
# 4    238980.0  40.822552 -73.867003  (40.822552032, -73.867003392)
#
#                                        geometry
# 0             POINT (-73.769745503 40.68378593)
# 1       POINT (-73.87839732800001 40.756298483)
# 2  POINT (-73.95311662899999 40.72696506699999)
# 3            POINT (-73.897849003 40.824518508)
# 4            POINT (-73.867003392 40.822552032)

# %%
dft2['Year']=dft2.Date.str[-4:]
dft2['Month']=dft2.Date.str[-10:-8]

# %%
dft2.groupby(by='Year')['ComplaintID'].count()
# Out:
# Year
# 1016         2
# 1017         1
# 1018        13
# 1025         1
# 1028         5
# 1948         1
# 1951         1
# 1969         1
# 1970         1
# 1971         2
# 1972         3
# 1973         3
# 1974         1
# 1977         3
# 1978         1
# 1979         1
# 1980         2
# 1982         2
# 1983         2
# 1985         1
# 1986         1
# 1989         1
# 1990         1
# 1991         5
# 1993         1
# 1994         5
# 1995         2
# 1996         1
# 1997         3
# 1998         8
# 1999         8
# 2000        14
# 2001        10
# 2002        11
# 2003        15
# 2004         8
# 2005        14
# 2006        12
# 2007        29
# 2008        33
# 2009        25
# 2010        56
# 2011        55
# 2012        74
# 2013        98
# 2014       126
# 2015       276
# 2016       544
# 2017      7397
# 2018    220025
# Name: ComplaintID, dtype: int64

# %%
dft2=dft2[(dft2['Year']=='2018')]

# %%
dft2.groupby(by='Year')['ComplaintID'].count()
# Out:
# Year
# 2018    220025
# Name: ComplaintID, dtype: int64

# %%
dft2['Datetime'] = dft2['Date'] + ' ' + dft2['Time']

# %%
dft2.tail()
# Out:
#         ComplaintID Neighborhood        Borough        Date      Time  \
# 228686    399428936           20      MANHATTAN  01/01/2018  00:00:00
# 228687    102069646           34      MANHATTAN  01/01/2018  00:00:00
# 228688    704995508          120  STATEN ISLAND  01/01/2018  00:00:00
# 228689    524021051           14      MANHATTAN  01/01/2018  00:00:00
# 228690    749162295           14      MANHATTAN  01/01/2018  00:00:00
#
#            Status        JURIS_DESC Offence Code Offence Level    Description  \
# 228686  COMPLETED  N.Y. POLICE DEPT          341   MISDEMEANOR  PETIT LARCENY
# 228687  COMPLETED  N.Y. POLICE DEPT          341   MISDEMEANOR  PETIT LARCENY
# 228688  COMPLETED  N.Y. POLICE DEPT          578     VIOLATION  HARRASSMENT 2
# 228689  COMPLETED  N.Y. POLICE DEPT          341   MISDEMEANOR  PETIT LARCENY
# 228690  COMPLETED  N.Y. POLICE DEPT          109        FELONY  GRAND LARCENY
#
#                ...              Premise Description X_COORD_CD Y_COORD_CD  \
# 228686         ...           RESIDENCE - APT. HOUSE   988047.0   220354.0
# 228687         ...           RESIDENCE - APT. HOUSE  1002777.0   248608.0
# 228688         ...           RESIDENCE - APT. HOUSE   961172.0   162476.0
# 228689         ...                   BAR/NIGHT CLUB   988555.0   210445.0
# 228690         ...                           STREET   988002.0   214967.0
#
#          Latitude  Longitude                        Lat_Lon  \
# 228686  40.771505 -73.986293  (40.771504594, -73.986293046)
# 228687  40.849035 -73.933035  (40.849035371, -73.933034994)
# 228688  40.612614 -74.083122  (40.612613627, -74.083122217)
# 228689  40.744307 -73.984465  (40.744306684, -73.984465345)
# 228690  40.756719 -73.986459  (40.756718685, -73.986458517)
#
#                                        geometry  Year Month  \
# 228686       POINT (-73.986293046 40.771504594)  2018    01
# 228687       POINT (-73.933034994 40.849035371)  2018    01
# 228688  POINT (-74.083122217 40.61261362699999)  2018    01
# 228689       POINT (-73.984465345 40.744306684)  2018    01
# 228690       POINT (-73.986458517 40.756718685)  2018    01
#
#                    Datetime
# 228686  01/01/2018 00:00:00
# 228687  01/01/2018 00:00:00
# 228688  01/01/2018 00:00:00
# 228689  01/01/2018 00:00:00
# 228690  01/01/2018 00:00:00
#
# [5 rows x 22 columns]

# %%
dft2["Date"] =pd.to_datetime(dft2['Date'], format='%m/%d/%Y')

# %%
dft2.set_index('Date',inplace=True)

# %%
dft2.drop(columns='Datetime',inplace=True)

# %%
dft2['Year']=dft2['Year'].astype('category')
dft2['Month']=dft2['Month'].astype('category')

# %%
#changing numerical data into str and then into categorical data
#dft2['Neighborhood']=dft2["Neighborhood"].astype(int).astype(str).astype('category')
dft2['Internal Code']=dft2["Internal Code"].astype(str).astype('category')
dft2['Offence Code']=dft2["Offence Code"].astype(str).astype('category')

# %%
#saving to CSV
dft2.to_csv("NYPD_data_cleand_data_v1.csv")
